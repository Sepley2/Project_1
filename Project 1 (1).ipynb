# %% [markdown]
# #Pre-Processing

# %%
#Firstly, let's import Pandas
import pandas as pd

# %%
#Import and read our CSV
poke_df = pd.read_csv("PokemonStats.csv")

# %%
#Let's check and see if it worked
poke_df
# Out:
#         ID                    Name  Total   HP  Attack  Defense  SpAtk  SpDef  \
# 0        1               Bulbasaur    318   45      49       49     65     65
# 1        2                 Ivysaur    405   60      62       63     80     80
# 2        3                Venusaur    525   80      82       83    100    100
# 3        3  Venusaur Mega Venusaur    625   80     100      123    122    120
# 4        4              Charmander    309   39      52       43     60     50
# ...    ...                     ...    ...  ...     ...      ...    ...    ...
# 1189  1006            Iron Valiant    590   74     130       90    120     60
# 1190  1007                Koraidon    670  100     135      115     85    100
# 1191  1008                Miraidon    670  100      85      100    135    115
# 1192  1009            Walking Wake    590   99      83       91    125     83
# 1193  1010             Iron Leaves    590   90     130       88     70    108
#
# ...

# %%
#Looking at our columns
poke_df.columns
# Out:
# Index(['ID', 'Name', 'Total', 'HP', 'Attack', 'Defense', 'SpAtk', 'SpDef',
#        'Speed', 'Type1', 'Type2', 'Height', 'Weight'],
#       dtype='object')

# %%
#Checking our data types
poke_df.dtypes
# Out:
# ID           int64
# Name        object
# Total        int64
# HP           int64
# Attack       int64
# Defense      int64
# SpAtk        int64
# SpDef        int64
# Speed        int64
# Type1       object
# Type2       object
# Height     float64
# Weight     float64
# dtype: object

# %%
#Alright, let's drop the columns we know we won't need and address our nulls
#For the purpose of my project, I will be dropping Height, Weight, and ID.
poke_df.drop('Height', axis=1, inplace=True)
#DroppingID
poke_df.drop('ID', axis=1, inplace=True)

# %%
#Dropping Weight
poke_df.drop('Weight', axis=1, inplace=True)

# %%
poke_df
# Out:
#                         Name  Total   HP  Attack  Defense  SpAtk  SpDef  \
# 0                  Bulbasaur    318   45      49       49     65     65
# 1                    Ivysaur    405   60      62       63     80     80
# 2                   Venusaur    525   80      82       83    100    100
# 3     Venusaur Mega Venusaur    625   80     100      123    122    120
# 4                 Charmander    309   39      52       43     60     50
# ...                      ...    ...  ...     ...      ...    ...    ...
# 1189            Iron Valiant    590   74     130       90    120     60
# 1190                Koraidon    670  100     135      115     85    100
# 1191                Miraidon    670  100      85      100    135    115
# 1192            Walking Wake    590   99      83       91    125     83
# 1193             Iron Leaves    590   90     130       88     70    108
#
#       Speed     Type1     Type2
# 0        45     Grass    Poison
# 1        60     Grass    Poison
# ...

# %%
#Next, lets look at our dreaded nulls
poke_df.isnull().sum()
# Out:
# Name         0
# Total        0
# HP           0
# Attack       0
# Defense      0
# SpAtk        0
# SpDef        0
# Speed        0
# Type1        0
# Type2      542
# dtype: int64

# %%
#Our only nulls are Type2 of course. :( Let's just change that to No Secondary Type
poke_df["Type2"].fillna("No Secondary Typing", inplace = True)

# %%
poke_df["Type2"]
# Out:
# 0                    Poison
# 1                    Poison
# 2                    Poison
# 3                    Poison
# 4       No Secondary Typing
#                ...
# 1189               Fighting
# 1190                 Dragon
# 1191                 Dragon
# 1192                 Dragon
# 1193                Psychic
# Name: Type2, Length: 1194, dtype: object

# %%
#Oops I made a mistake. No Secondary Typing looks kinda janky. Let's fix that.
poke_df['Type2'].replace({'No Secondary Typing': 'No Type'}, inplace=True)

# %%
poke_df['Type2']
# Out:
# 0         Poison
# 1         Poison
# 2         Poison
# 3         Poison
# 4        No Type
#           ...
# 1189    Fighting
# 1190      Dragon
# 1191      Dragon
# 1192      Dragon
# 1193     Psychic
# Name: Type2, Length: 1194, dtype: object

# %%
#It worked! Now, we should have no null values. Let's recheck.
poke_df.isnull().sum()
# Out:
# Name       0
# Total      0
# HP         0
# Attack     0
# Defense    0
# SpAtk      0
# SpDef      0
# Speed      0
# Type1      0
# Type2      0
# dtype: int64

# %%
#Perfect! No more Nulls. I hate those guys
poke_df
# Out:
#                         Name  Total   HP  Attack  Defense  SpAtk  SpDef  \
# 0                  Bulbasaur    318   45      49       49     65     65
# 1                    Ivysaur    405   60      62       63     80     80
# 2                   Venusaur    525   80      82       83    100    100
# 3     Venusaur Mega Venusaur    625   80     100      123    122    120
# 4                 Charmander    309   39      52       43     60     50
# ...                      ...    ...  ...     ...      ...    ...    ...
# 1189            Iron Valiant    590   74     130       90    120     60
# 1190                Koraidon    670  100     135      115     85    100
# 1191                Miraidon    670  100      85      100    135    115
# 1192            Walking Wake    590   99      83       91    125     83
# 1193             Iron Leaves    590   90     130       88     70    108
#
#       Speed     Type1     Type2
# 0        45     Grass    Poison
# 1        60     Grass    Poison
# ...

# %%
#I am being a perfectionist, so let's rename our Type1 and Type2 column to more accurately reflect how typing works
poke_df.rename(columns={'Type1': 'Primary Type', 'Type2': 'Secondary Type'}, inplace=True)
poke_df
# Out:
#                         Name  Total   HP  Attack  Defense  SpAtk  SpDef  \
# 0                  Bulbasaur    318   45      49       49     65     65
# 1                    Ivysaur    405   60      62       63     80     80
# 2                   Venusaur    525   80      82       83    100    100
# 3     Venusaur Mega Venusaur    625   80     100      123    122    120
# 4                 Charmander    309   39      52       43     60     50
# ...                      ...    ...  ...     ...      ...    ...    ...
# 1189            Iron Valiant    590   74     130       90    120     60
# 1190                Koraidon    670  100     135      115     85    100
# 1191                Miraidon    670  100      85      100    135    115
# 1192            Walking Wake    590   99      83       91    125     83
# 1193             Iron Leaves    590   90     130       88     70    108
#
#       Speed Primary Type Secondary Type
# 0        45        Grass         Poison
# ...

# %%
#She's beautiful! Really liking the way this turned out. Now, it is time to have fun with numbers
##Let's import seaborn, matplotlib, and numpy
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#PRIMARY TYPE GRAPHS

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='Attack').set(title="Average Attack by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average Attack by Primary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='Defense').set(title="Average Defense by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average Defense by Primary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='SpAtk').set(title="Average Special Attack by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average Special Attack by Primary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='SpDef').set(title="Average Special Defense by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average Special Defense by Primary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='Speed').set(title="Average Speed by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average Speed by Primary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='HP').set(title="Average HP by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average HP by Primary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=poke_df, x='Primary Type' , y='Total').set(title="Average Total Stats by Primary Type")
# Out:
# [Text(0.5, 1.0, 'Average Total Stats by Primary Type')]

# %%
#Secondary typing
#We have to filter out "No Type" from our findings
pokedf_filter = poke_df[poke_df['Secondary Type'] != 'No Type']

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='Attack').set(title="Average Attack by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average Attack by Secondary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='Defense').set(title="Average Defense by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average Defense by Secondary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='SpAtk').set(title="Average Special Attack by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average Special Attack by Secondary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='SpDef').set(title="Average Special Defense by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average Special Defense by Secondary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='HP').set(title="Average HP by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average HP by Secondary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='Speed').set(title="Average Speed by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average Speed by Secondary Type')]

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.20)
sns.barplot(data=pokedf_filter, x='Secondary Type' , y='Total').set(title="Average Total Stats by Secondary Type")
# Out:
# [Text(0.5, 1.0, 'Average Total Stats by Secondary Type')]

# %%
#Let's make a barplot about the type counts
type_counts = poke_df.groupby(['Primary Type']).size()
type_counts
# Out:
# Primary Type
# Bug          91
# Dark         56
# Dragon       49
# Electric     73
# Fairy        31
# Fighting     50
# Fire         75
# Flying       10
# Ghost        47
# Grass       105
# Ground       46
# Ice          43
# Normal      131
# Poison       45
# Psychic      82
# Rock         67
# Steel        43
# Water       150
# dtype: int64

# %%
#Getting our Primary Type plot
type_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='Primary Type'>

# %%
#Using the PokeDF filter I established before, getting our secondary typing plot without no type
type_counts2 = pokedf_filter.groupby(['Secondary Type']).size()
type_counts2
# Out:
# Secondary Type
# Bug           9
# Dark         33
# Dragon       39
# Electric     13
# Fairy        42
# Fighting     41
# Fire         20
# Flying      122
# Ghost        37
# Grass        33
# Ground       43
# Ice          22
# Normal       18
# Poison       47
# Psychic      49
# Rock         19
# Steel        40
# Water        25
# dtype: int64

# %%
#Number of Secondary Typings by Type
type_counts2.plot(kind="bar")
# Out:
# <Axes: xlabel='Secondary Type'>

# %%
#Getting number of No Type
type_count3 = poke_df.groupby(['Secondary Type']).size()

# %%
type_count3.plot(kind="bar")
# Out:
# <Axes: xlabel='Secondary Type'>

# %%
# Out:
# [Text(0.5, 1.0, 'Average Speed by Primary Type')]
